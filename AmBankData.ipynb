# %%
import camelot

# %%
file_pathMayabank2023 = "C:/Users/Dell/Downloads/Malaysia Islamic Banks/AMBANK ISLAMIC/financial-report-2023.pdf"
file_pathMayabank2021 = "C:/Users/Dell/Downloads/Malaysia Islamic Banks/AMBANK ISLAMIC/ammb-governance-and-financial-report-2021.pdf"
file_pathMayabank2019 = "C:/Users/Dell/Downloads/Malaysia Islamic Banks/AMBANK ISLAMIC/ammb-2019-annual-report-(financial).pdf"
file_pathMayabank2016 = "C:/Users/Dell/Downloads/Malaysia Islamic Banks/AMBANK ISLAMIC/ammbfr2017.pdf"
file_pathMayabank2017 = "C:/Users/Dell/Downloads/Malaysia Islamic Banks/AMBANK ISLAMIC/ambankfr2018.pdf"
file_pathMayabank2015 = "C:/Users/Dell/Downloads/Malaysia Islamic Banks/AMBANK ISLAMIC/ambank-cover-to-back.pdf"
file_pathMayabank2024 = "C:/Users/Dell/Downloads/Malaysia Islamic Banks/AMBANK ISLAMIC/ammb_fr24_190724.pdf"

# %%
AMBANK2015 = camelot.read_pdf(
    file_pathMayabank2015,
    pages="313",          # or the actual page(s) of your table
    flavor="stream"      # try "stream" instead of "lattice"
)
AMBANK2016 = camelot.read_pdf(
    file_pathMayabank2016,
    pages="240",          # or the actual page(s) of your table
    flavor="stream"      # try "stream" instead of "lattice"
)
AMBANK2017 = camelot.read_pdf(
    file_pathMayabank2017,
    pages="220",          # or the actual page(s) of your table
    flavor="stream"      # try "stream" instead of "lattice"
)
AMBANK2018 = camelot.read_pdf(
    file_pathMayabank2019,
    pages="273",          # or the actual page(s) of your table
    flavor="stream"      # try "stream" instead of "lattice"
)
AMBANK2019 = camelot.read_pdf(
    file_pathMayabank2019,
    pages="272",          # or the actual page(s) of your table
    flavor="stream"      # try "stream" instead of "lattice"
)


AMBANK2020 = camelot.read_pdf(
    file_pathMayabank2021,
    pages="315",          # or the actual page(s) of your table
    flavor="stream"      # try "stream" instead of "lattice"
)
AMBANK2021 = camelot.read_pdf(
    file_pathMayabank2021,
    pages="314",          # or the actual page(s) of your table
    flavor="stream"      # try "stream" instead of "lattice"
)

AMBANK2022 = camelot.read_pdf(
    file_pathMayabank2023,
    pages="251",          # or the actual page(s) of your table
    flavor="stream"      # try "stream" instead of "lattice"
)
AMBANK2023 = camelot.read_pdf(
    file_pathMayabank2023,
    pages="250",          # or the actual page(s) of your table
    flavor="stream"      # try "stream" instead of "lattice"
)
AMBANK2024 = camelot.read_pdf(
    file_pathMayabank2024,
    pages="250",          # or the actual page(s) of your table
    flavor="stream"      # try "stream" instead of "lattice"
)

# %%
for i, table in enumerate(AMBANK2015):
    table.to_csv(f"2015{i}.csv")      # or table.to_excel(...)
    print(f"Saved 2013{i}.csv")
for i, table in enumerate(AMBANK2016):
    table.to_csv(f"2016{i}.csv")      # or table.to_excel(...)
    print(f"Saved 2016{i}.csv")
for i, table in enumerate(AMBANK2017):
    table.to_csv(f"2017{i}.csv")      # or table.to_excel(...)
    print(f"Saved 2017{i}.csv")
for i, table in enumerate(AMBANK2018):
    table.to_csv(f"2018{i}.csv")      # or table.to_excel(...)
    print(f"Saved 2018{i}.csv")
for i, table in enumerate(AMBANK2019):
    table.to_csv(f"2019{i}.csv")      # or table.to_excel(...)
    print(f"Saved 2019{i}.csv")
for i, table in enumerate(AMBANK2020):
    table.to_csv(f"2020{i}.csv")      # or table.to_excel(...)
    print(f"Saved 2020{i}.csv")
for i, table in enumerate(AMBANK2021):
    table.to_csv(f"2021{i}.csv")      # or table.to_excel(...)
    print(f"Saved 2021{i}.csv")
for i, table in enumerate(AMBANK2022):
    table.to_csv(f"2022{i}.csv")      # or table.to_excel(...)
    print(f"Saved 2022{i}.csv")
for i, table in enumerate(AMBANK2023):
    table.to_csv(f"2023{i}.csv")      # or table.to_excel(...)
    print(f"Saved 2023{i}.csv")
for i, table in enumerate(AMBANK2024):
    table.to_csv(f"2024{i}.csv")      # or table.to_excel(...)
    print(f"Saved 2024{i}.csv")
# Out:
# Saved 20130.csv
# Saved 20131.csv
# Saved 20160.csv
# Saved 20170.csv
# Saved 20180.csv
# Saved 20190.csv
# Saved 20200.csv
# Saved 20210.csv
# Saved 20220.csv
# Saved 20230.csv
# Saved 20240.csv
# Saved 20241.csv
# Saved 20242.csv

# %%
import pandas as pd
import glob
import os

# Find all CSV files in the current directory
csv_files = glob.glob("*.csv")

# Create an Excel writer object to save multiple sheets
with pd.ExcelWriter("AMBANK_sheets.xlsx", engine="openpyxl") as writer:
    for file in csv_files:
        df = pd.read_csv(file)
        # Use the CSV filename (without extension) as the sheet name
        sheet_name = os.path.splitext(os.path.basename(file))[0]
        # Save the DataFrame to a sheet in the workbook
        df.to_excel(writer, sheet_name=sheet_name, index=False)

print("Merged Excel workbook saved as 'AMBANK_sheets.xlsx'.")
# Out:
# Merged Excel workbook saved as 'AMBANK_sheets.xlsx'.

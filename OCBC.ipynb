# %%
import camelot

# %%
file_pathMayabank2014 = "C:/Users/Dell/Downloads/Malaysia Islamic Banks/OCBC AL-Amin Bank/OCBC_AlAmin_Reports_and_Financial_Statements_FY2014.pdf"
file_pathMayabank2016 = "C:/Users/Dell/Downloads/Malaysia Islamic Banks/OCBC AL-Amin Bank/OCBC_AlAmin_Reports_and_Financial_Statements_FY2016.pdf"
file_pathMayabank2018 = "C:/Users/Dell/Downloads/Malaysia Islamic Banks/OCBC AL-Amin Bank/AA FS Dec2018.pdf"
file_pathMayabank2020 = "C:/Users/Dell/Downloads/Malaysia Islamic Banks/OCBC AL-Amin Bank/Stat Dec2020.pdf"
file_pathMayabank2022 = "C:/Users/Dell/Downloads/Malaysia Islamic Banks/OCBC AL-Amin Bank/OABB Annual Financial Statements FY2022.pdf"
file_pathMayabank2024 = "C:/Users/Dell/Downloads/Malaysia Islamic Banks/OCBC AL-Amin Bank/3Q24 OABB Interim Financial Statements.pdf"

# %%
OCBC2013 = camelot.read_pdf(
    file_pathMayabank2014,
    pages="39",          # or the actual page(s) of your table
    flavor="stream"      # try "stream" instead of "lattice"
)
OCBC2014 = camelot.read_pdf(
    file_pathMayabank2014,
    pages="38",          # or the actual page(s) of your table
    flavor="stream"      # try "stream" instead of "lattice"
)
OCBC2015 = camelot.read_pdf(
    file_pathMayabank2016,
    pages="43",          # or the actual page(s) of your table
    flavor="stream"      # try "stream" instead of "lattice"
)
OCBC2016 = camelot.read_pdf(
    file_pathMayabank2016,
    pages="42",          # or the actual page(s) of your table
    flavor="stream"      # try "stream" instead of "lattice"
)
OCBC2017 = camelot.read_pdf(
    file_pathMayabank2018,
    pages="48",          # or the actual page(s) of your table
    flavor="stream"      # try "stream" instead of "lattice"
)
OCBC2018 = camelot.read_pdf(
    file_pathMayabank2018,
    pages="47",          # or the actual page(s) of your table
    flavor="stream"      # try "stream" instead of "lattice"
)
OCBC2019 = camelot.read_pdf(
    file_pathMayabank2020,
    pages="49",          # or the actual page(s) of your table
    flavor="stream"      # try "stream" instead of "lattice"
)
OCBC2020 = camelot.read_pdf(
    file_pathMayabank2020,
    pages="48",          # or the actual page(s) of your table
    flavor="stream"      # try "stream" instead of "lattice"
)
OCBC2021 = camelot.read_pdf(
    file_pathMayabank2022,
    pages="48",          # or the actual page(s) of your table
    flavor="stream"      # try "stream" instead of "lattice"
)

OCBC2022 = camelot.read_pdf(
    file_pathMayabank2022,
    pages="47",          # or the actual page(s) of your table
    flavor="stream"      # try "stream" instead of "lattice"
)
OCBC2023 = camelot.read_pdf(
    file_pathMayabank2024,
    pages="12",          # or the actual page(s) of your table
    flavor="stream"      # try "stream" instead of "lattice"
)
OCBC2024 = camelot.read_pdf(
    file_pathMayabank2024,
    pages="11",          # or the actual page(s) of your table
    flavor="stream"      # try "stream" instead of "lattice"
)

# %%
for i, table in enumerate(OCBC2013):
    table.to_csv(f"2013{i}.csv")      # or table.to_excel(...)
    print(f"Saved 2013{i}.csv")
for i, table in enumerate(OCBC2014):
    table.to_csv(f"2014{i}.csv")      # or table.to_excel(...)
    print(f"Saved 2014{i}.csv")
for i, table in enumerate(OCBC2015):
    table.to_csv(f"2015{i}.csv")      # or table.to_excel(...)
    print(f"Saved 2015{i}.csv")
for i, table in enumerate(OCBC2016):
    table.to_csv(f"2016{i}.csv")      # or table.to_excel(...)
    print(f"Saved 2016{i}.csv")
for i, table in enumerate(OCBC2017):
    table.to_csv(f"2017{i}.csv")      # or table.to_excel(...)
    print(f"Saved 2017{i}.csv")
for i, table in enumerate(OCBC2018):
    table.to_csv(f"2018{i}.csv")      # or table.to_excel(...)
    print(f"Saved 2018{i}.csv")
for i, table in enumerate(OCBC2019):
    table.to_csv(f"2019{i}.csv")      # or table.to_excel(...)
    print(f"Saved 2019{i}.csv")
for i, table in enumerate(OCBC2020):
    table.to_csv(f"2020{i}.csv")      # or table.to_excel(...)
    print(f"Saved 2020{i}.csv")
for i, table in enumerate(OCBC2021):
    table.to_csv(f"2021{i}.csv")      # or table.to_excel(...)
    print(f"Saved 2021{i}.csv")
for i, table in enumerate(OCBC2022):
    table.to_csv(f"2022{i}.csv")      # or table.to_excel(...)
    print(f"Saved 2022{i}.csv")
for i, table in enumerate(OCBC2023):
    table.to_csv(f"2023{i}.csv")      # or table.to_excel(...)
    print(f"Saved 2023{i}.csv")
for i, table in enumerate(OCBC2024):
    table.to_csv(f"2024{i}.csv")      # or table.to_excel(...)
    print(f"Saved 2024{i}.csv")
# Out:
# Saved 20130.csv
# Saved 20140.csv
# Saved 20141.csv
# Saved 20150.csv
# Saved 20160.csv
# Saved 20161.csv
# Saved 20170.csv
# Saved 20180.csv
# Saved 20190.csv
# Saved 20200.csv
# Saved 20210.csv
# Saved 20220.csv
# Saved 20230.csv
# Saved 20240.csv

# %%
import pandas as pd
import glob
import os

# Find all CSV files in the current directory
csv_files = glob.glob("*.csv")

# Create an Excel writer object to save multiple sheets
with pd.ExcelWriter("OCBC_sheets.xlsx", engine="openpyxl") as writer:
    for file in csv_files:
        df = pd.read_csv(file)
        # Use the CSV filename (without extension) as the sheet name
        sheet_name = os.path.splitext(os.path.basename(file))[0]
        # Save the DataFrame to a sheet in the workbook
        df.to_excel(writer, sheet_name=sheet_name, index=False)

print("Merged Excel workbook saved as 'OCBC_sheets.xlsx'.")
# Out:
# Merged Excel workbook saved as 'OCBC_sheets.xlsx'.

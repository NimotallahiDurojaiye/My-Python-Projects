# %%
# !pip install camelot-py[cv]
# Out:
# ...
# WARNING: camelot-py 1.0.0 does not provide the extra 'cv'

# %%
import camelot

# %%
file_pathMayabank2010 = "C:/Users/Dell/Downloads/Malaysia Islamic Banks/ICM Banks ASS/maybank/20100906_Maybank-Annual-Report-2010.pdf"
file_pathMayabank2011 = "C:/Users/Dell/Downloads/Malaysia Islamic Banks/ICM Banks ASS/maybank/20110909_Maybank_Annual_Report_2011.pdf"
file_pathMayabank2012 = "C:/Users/Dell/Downloads/Malaysia Islamic Banks/ICM Banks ASS/maybank/Maybank_AR2012-Financial_Statements.pdf"
file_pathMayabank2013 = "C:/Users/Dell/Downloads/Malaysia Islamic Banks/ICM Banks ASS/maybank/Maybank-AR2013-Financial-Statements.pdf"
file_pathMayabank2014 = "C:/Users/Dell/Downloads/Malaysia Islamic Banks/ICM Banks ASS/maybank/Maybank_AR2014-Financial_Statements.pdf"
file_pathMayabank2015 = "C:/Users/Dell/Downloads/Malaysia Islamic Banks/ICM Banks ASS/maybank/Maybank_AR2015-Financial_Statements_Book.pdf"
file_pathMayabank2016 = "C:/Users/Dell/Downloads/Malaysia Islamic Banks/ICM Banks ASS/maybank/Maybank_AR2016-Financial_Statements_Book.pdf"
file_pathMayabank2017 = "C:/Users/Dell/Downloads/Malaysia Islamic Banks/ICM Banks ASS/maybank/Maybank_AR2017-Financial_Statements_Book.pdf"
file_pathMayabank2018 = "C:/Users/Dell/Downloads/Malaysia Islamic Banks/ICM Banks ASS/maybank/Maybank_AR2019-Financial_Statements_Book.pdf"
file_pathMayabank2019 = "C:/Users/Dell/Downloads/Malaysia Islamic Banks/ICM Banks ASS/maybank/Maybank_AR2019-Financial_Statements_Book.pdf"
file_pathMayabank2020 = "C:/Users/Dell/Downloads/Malaysia Islamic Banks/ICM Banks ASS/maybank/Maybank_AR2020-Financial_Statements_Book_.pdf"
file_pathMayabank2021 = "C:/Users/Dell/Downloads/Malaysia Islamic Banks/ICM Banks ASS/maybank/Maybank-AR2021-Financial-Statements-Book.pdf"
file_pathMayabank2022 = "C:/Users/Dell/Downloads/Malaysia Islamic Banks/ICM Banks ASS/maybank/Maybank-AR2023-Financial-Statements.pdf"
file_pathMayabank2023 = "C:/Users/Dell/Downloads/Malaysia Islamic Banks/ICM Banks ASS/maybank/Maybank-AR2023-Financial-Statements.pdf"

# %%
MAYBANK2010 = camelot.read_pdf(
    file_pathMayabank2010,
    pages="399",          # or the actual page(s) of your table
    flavor="stream"      # try "stream" instead of "lattice"
)
MAYBANK2011 = camelot.read_pdf(
    file_pathMayabank2011,
    pages="423",          # or the actual page(s) of your table
    flavor="stream"      # try "stream" instead of "lattice"
)
MAYBANK2012 = camelot.read_pdf(
    file_pathMayabank2012,
    pages="423",          # or the actual page(s) of your table
    flavor="stream"      # try "stream" instead of "lattice"
)
MAYBANK2013 = camelot.read_pdf(
    file_pathMayabank2013,
    pages="188",          # or the actual page(s) of your table
    flavor="stream"      # try "stream" instead of "lattice"
)
MAYBANK2014 = camelot.read_pdf(
    file_pathMayabank2014,
    pages="220",          # or the actual page(s) of your table
    flavor="stream"      # try "stream" instead of "lattice"
)
MAYBANK2015 = camelot.read_pdf(
    file_pathMayabank2015,
    pages="244",          # or the actual page(s) of your table
    flavor="stream"      # try "stream" instead of "lattice"
)
MAYBANK2016 = camelot.read_pdf(
    file_pathMayabank2016,
    pages="229",          # or the actual page(s) of your table
    flavor="stream"      # try "stream" instead of "lattice"
)
MAYBANK2017 = camelot.read_pdf(
    file_pathMayabank2017,
    pages="258",          # or the actual page(s) of your table
    flavor="stream"      # try "stream" instead of "lattice"
)
MAYBANK2018 = camelot.read_pdf(
    file_pathMayabank2019,
    pages="243",          # or the actual page(s) of your table
    flavor="stream"      # try "stream" instead of "lattice"
)
MAYBANK2019 = camelot.read_pdf(
    file_pathMayabank2019,
    pages="242",          # or the actual page(s) of your table
    flavor="stream"      # try "stream" instead of "lattice"
)
MAYBANK2020 = camelot.read_pdf(
    file_pathMayabank2020,
    pages="237",          # or the actual page(s) of your table
    flavor="stream"      # try "stream" instead of "lattice"
)
MAYBANK2021 = camelot.read_pdf(
    file_pathMayabank2021,
    pages="237",          # or the actual page(s) of your table
    flavor="stream"      # try "stream" instead of "lattice"
)
MAYBANK2022 = camelot.read_pdf(
    file_pathMayabank2023,
    pages="268",          # or the actual page(s) of your table
    flavor="stream"      # try "stream" instead of "lattice"
)
MAYBANK2023 = camelot.read_pdf(
    file_pathMayabank2023,
    pages="267",          # or the actual page(s) of your table
    flavor="stream"      # try "stream" instead of "lattice"
)

# %%
for i, table in enumerate(MAYBANK2010):
    table.to_csv(f"2010{i}.csv")      # or table.to_excel(...)
    print(f"Saved 2010{i}.csv")
for i, table in enumerate(MAYBANK2011):
    table.to_csv(f"2011{i}.csv")      # or table.to_excel(...)
    print(f"Saved 2011{i}.csv")
for i, table in enumerate(MAYBANK2012):
    table.to_csv(f"2012{i}.csv")      # or table.to_excel(...)
    print(f"Saved 2012{i}.csv")
for i, table in enumerate(MAYBANK2013):
    table.to_csv(f"2013{i}.csv")      # or table.to_excel(...)
    print(f"Saved 2013{i}.csv")
for i, table in enumerate(MAYBANK2014):
    table.to_csv(f"2014{i}.csv")      # or table.to_excel(...)
    print(f"Saved 2014{i}.csv")
for i, table in enumerate(MAYBANK2015):
    table.to_csv(f"2015{i}.csv")      # or table.to_excel(...)
    print(f"Saved 2015{i}.csv")
for i, table in enumerate(MAYBANK2016):
    table.to_csv(f"2016{i}.csv")      # or table.to_excel(...)
    print(f"Saved 2016{i}.csv")
for i, table in enumerate(MAYBANK2017):
    table.to_csv(f"2017{i}.csv")      # or table.to_excel(...)
    print(f"Saved 2017{i}.csv")
for i, table in enumerate(MAYBANK2018):
    table.to_csv(f"2018{i}.csv")      # or table.to_excel(...)
    print(f"Saved 2018{i}.csv")
for i, table in enumerate(MAYBANK2019):
    table.to_csv(f"2019{i}.csv")      # or table.to_excel(...)
    print(f"Saved 2019{i}.csv")
for i, table in enumerate(MAYBANK2020):
    table.to_csv(f"2020{i}.csv")      # or table.to_excel(...)
    print(f"Saved 2020{i}.csv")
for i, table in enumerate(MAYBANK2021):
    table.to_csv(f"2021{i}.csv")      # or table.to_excel(...)
    print(f"Saved 2021{i}.csv")
for i, table in enumerate(MAYBANK2022):
    table.to_csv(f"2022{i}.csv")      # or table.to_excel(...)
    print(f"Saved 2022{i}.csv")
for i, table in enumerate(MAYBANK2023):
    table.to_csv(f"2023{i}.csv")      # or table.to_excel(...)
    print(f"Saved 2023{i}.csv")
# Out:
# Saved 20100.csv
# Saved 20110.csv
# Saved 20120.csv
# Saved 20130.csv
# Saved 20131.csv
# Saved 20132.csv
# Saved 20140.csv
# Saved 20141.csv
# Saved 20150.csv
# Saved 20160.csv
# Saved 20161.csv
# Saved 20170.csv
# Saved 20180.csv
# Saved 20181.csv
# Saved 20190.csv
# Saved 20200.csv
# Saved 20210.csv
# Saved 20220.csv
# Saved 20230.csv

# %%
import pandas as pd
from openpyxl import Workbook
from openpyxl.utils.dataframe import dataframe_to_rows

# Create a Pandas Excel writer using openpyxl as the engine
excel_file = 'Maybank_Financial_Data_2010_2023.xlsx'
writer = pd.ExcelWriter(excel_file, engine='openpyxl')

# Dictionary to store all tables
all_tables = {
    "2010": MAYBANK2010,
    "2011": MAYBANK2011,
    "2012": MAYBANK2012,
    "2013": MAYBANK2013,
    "2014": MAYBANK2014,
    "2015": MAYBANK2015,
    "2016": MAYBANK2016,
    "2017": MAYBANK2017,
    "2018": MAYBANK2018,
    "2019": MAYBANK2019,
    "2020": MAYBANK2020,
    "2021": MAYBANK2021,
    "2022": MAYBANK2022,
    "2023": MAYBANK2023
}

# Write each table to a different worksheet
for year, tables in all_tables.items():
    for i, table in enumerate(tables):
        sheet_name = f'{year}_Table{i}'
        # Ensure sheet name is valid (31 chars max for Excel)
        if len(sheet_name) > 31:
            sheet_name = f'{year}T{i}'
            
        # Convert table to dataframe and write to Excel
        df = table.df
        df.to_excel(writer, sheet_name=sheet_name, index=False)
        print(f"Added {year} Table {i} to Excel file")

# Save the Excel file
writer.close()
print(f"All tables successfully saved to {excel_file}")
# Out:
# Added 2010 Table 0 to Excel file
# Added 2011 Table 0 to Excel file
# Added 2012 Table 0 to Excel file
# Added 2013 Table 0 to Excel file
# Added 2013 Table 1 to Excel file
# Added 2013 Table 2 to Excel file
# Added 2014 Table 0 to Excel file
# Added 2014 Table 1 to Excel file
# Added 2015 Table 0 to Excel file
# Added 2016 Table 0 to Excel file
# Added 2016 Table 1 to Excel file
# Added 2017 Table 0 to Excel file
# Added 2018 Table 0 to Excel file
# Added 2018 Table 1 to Excel file
# Added 2019 Table 0 to Excel file
# Added 2020 Table 0 to Excel file
# Added 2021 Table 0 to Excel file
# Added 2022 Table 0 to Excel file
# Added 2023 Table 0 to Excel file
# All tables successfully saved to Maybank_Financial_Data_2010_2023.xlsx

# %%
import pandas as pd

# Specify the path to save to your Maybank folder
excel_file = "C:/Users/Dell/Downloads/Malaysia Islamic Banks/ICM Banks ASS/maybank/Maybank_Financial_Data_2010_2023.xlsx"
writer = pd.ExcelWriter(excel_file, engine='openpyxl')

# Dictionary to store all tables
all_tables = {
    "2010": MAYBANK2010,
    "2011": MAYBANK2011,
    "2012": MAYBANK2012,
    "2013": MAYBANK2013,
    "2014": MAYBANK2014,
    "2015": MAYBANK2015,
    "2016": MAYBANK2016,
    "2017": MAYBANK2017,
    "2018": MAYBANK2018,
    "2019": MAYBANK2019,
    "2020": MAYBANK2020,
    "2021": MAYBANK2021,
    "2022": MAYBANK2022,
    "2023": MAYBANK2023
}

# Write each table to a different worksheet
for year, tables in all_tables.items():
    for i, table in enumerate(tables):
        sheet_name = f'{year}_Table{i}'
        # Ensure sheet name is valid (31 chars max for Excel)
        if len(sheet_name) > 31:
            sheet_name = f'{year}T{i}'
            
        # Convert table to dataframe and write to Excel
        df = table.df
        df.to_excel(writer, sheet_name=sheet_name, index=False)
        print(f"Added {year} Table {i} to Excel file")

# Save the Excel file
writer.close()
print(f"All tables successfully saved to {excel_file}")
# Out:
# Added 2010 Table 0 to Excel file
# Added 2011 Table 0 to Excel file
# Added 2012 Table 0 to Excel file
# Added 2013 Table 0 to Excel file
# Added 2013 Table 1 to Excel file
# Added 2013 Table 2 to Excel file
# Added 2014 Table 0 to Excel file
# Added 2014 Table 1 to Excel file
# Added 2015 Table 0 to Excel file
# Added 2016 Table 0 to Excel file
# Added 2016 Table 1 to Excel file
# Added 2017 Table 0 to Excel file
# Added 2018 Table 0 to Excel file
# Added 2018 Table 1 to Excel file
# Added 2019 Table 0 to Excel file
# Added 2020 Table 0 to Excel file
# Added 2021 Table 0 to Excel file
# Added 2022 Table 0 to Excel file
# Added 2023 Table 0 to Excel file
# All tables successfully saved to C:/Users/Dell/Downloads/Malaysia Islamic Banks/ICM Banks ASS/maybank/Maybank_Financial_Data_2010_2023.xlsx

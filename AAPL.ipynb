# %%
#import pandas library and name it pd
import pandas as pd

# %%
#create a dataframe by reading AAPL file
df=pd.read_excel('C:\\pyt\\AAPL.xlsx')

# %%
#list first five data
df.head()
# Out:
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2023-06-26  186.830002  188.050003  185.229996  185.270004  184.291275
# 1 2023-06-27  185.889999  188.389999  185.669998  188.059998  187.066544
# 2 2023-06-28  187.929993  189.899994  187.600006  189.250000  188.250244
# 3 2023-06-29  189.080002  190.070007  188.940002  189.589996  188.588455
# 4 2023-06-30  191.630005  194.479996  191.259995  193.970001  192.945328
#
#      Volume
# 0  48088700
# 1  50730800
# 2  51216800
# 3  46347300
# 4  85069600

# %%
#list last five rows
df.tail()
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 247 2024-06-18  217.589996  218.630005  213.000000  214.289993  214.289993
# 248 2024-06-20  213.929993  214.240005  208.850006  209.679993  209.679993
# 249 2024-06-21  210.389999  211.889999  207.110001  207.490005  207.490005
# 250 2024-06-24  207.720001  212.699997  206.589996  208.139999  208.139999
# 251 2024-06-25  209.149994  211.380005  208.610001  209.070007  209.070007
#
#         Volume
# 247   79943300
# 248   86172500
# 249  246421400
# 250   80727000
# 251   55549700

# %%
#list first two rows
df.head(2)
# Out:
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2023-06-26  186.830002  188.050003  185.229996  185.270004  184.291275
# 1 2023-06-27  185.889999  188.389999  185.669998  188.059998  187.066544
#
#      Volume
# 0  48088700
# 1  50730800

# %%
#print average volume
df['Volume'].mean()
# Out:
# 60161911.11111111

# %%
#get maximum open price
df['Open'].max()
# Out:
# 217.589996

# %%
#display column name
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
#print summmary info of the data frame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 252 entries, 0 to 251
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       252 non-null    datetime64[ns]
#  1   Open       252 non-null    float64
#  2   High       252 non-null    float64
#  3   Low        252 non-null    float64
#  4   Close      252 non-null    float64
#  5   Adj Close  252 non-null    float64
#  6   Volume     252 non-null    int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 13.9 KB

# %%
#calculate the HPR
df['HPR']=df['Close']/df['Open']

# %%
df.head(2)
# Out:
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2023-06-26  186.830002  188.050003  185.229996  185.270004  184.291275
# 1 2023-06-27  185.889999  188.389999  185.669998  188.059998  187.066544
#
#      Volume       HPR       HPY     Range
# 0  48088700  0.991650  0.008350  2.820007
# 1  50730800  1.011674 -0.011674  2.720001

# %%
#calculate the HPY
df['HPY']=df['HPR']-1

# %%
df.head(3)
# Out:
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2023-06-26  186.830002  188.050003  185.229996  185.270004  184.291275
# 1 2023-06-27  185.889999  188.389999  185.669998  188.059998  187.066544
# 2 2023-06-28  187.929993  189.899994  187.600006  189.250000  188.250244
#
#      Volume       HPR       HPY     Range
# 0  48088700  0.991650 -0.008350  2.820007
# 1  50730800  1.011674  0.011674  2.720001
# 2  51216800  1.007024  0.007024  2.299988

# %%
df['Range']=df['High']-df['Low']

# %% [markdown]
# df.head(1)

# %%
#import numpy as np
import numpy as np

# %%
np.mean(df['HPY'])
# Out:
# 0.000491986555645473

# %%
df.to_excel('C:\\pyt\\output.xlsx', index=False)
